# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import jax.numpy as jnp # Using jax.numpy for consistency if needed, but np is fine too
import os
import matplotlib.pyplot as plt # For potential plotting if scores are visualized
import csv

# %%
reference_trajectory_file = '/path to /dmp_ref.npy' 

loaded_data = np.load(reference_trajectory_file, allow_pickle=True)

reference_trajectory= loaded_data

# %%
import numpy as np
import torch


def smoothness_loss(pred):
   
    dx = torch.diff(pred[:, :, 0], dim=0)
    dy = torch.diff(pred[:, :, 1], dim=0)
    d1 = dx**2 + dy**2
    loss_d1 = torch.sum(d1)
    
    ddx = torch.diff(dx, dim=0)
    ddy = torch.diff(dy, dim=0)
    d2 = ddx**2 + ddy**2
    loss_d2 = torch.sum(d2)
    
    dddx = torch.diff(ddx, dim=0)
    dddy = torch.diff(ddy, dim=0)
    d3 = dddx**2 + dddy**2
    loss_d3 = torch.sum(d3)
    
    loss = 0.2 * loss_d1 + 0.3 * loss_d2 + 0.5 * loss_d3
    
    return loss
 
def closed_shape_loss(pred):
    
    return torch.norm(pred[:,:,0] - pred[:,:,-1])
 
def symmetry_loss(pred):

    pred_squeezed = pred.squeeze(1) 
    centroid = torch.mean(pred_squeezed, dim=0)
    reflected_x = 2 * centroid[0] - pred_squeezed[:, 0]
    reflected_points = torch.stack((reflected_x, pred_squeezed[:, 1]), dim=1)
    
    diff = reflected_points[:, None, :] - pred_squeezed[None, :, :]
    dists = torch.norm(diff, dim=2)
    min_dists, _ = torch.min(dists, dim=1)
    
    return torch.mean(min_dists)
 
def shape_preservation_loss(pred, dmp_trajectory, weight_edge=1):

    dmp_tensor_unsqueezed = dmp_trajectory.unsqueeze(1)
    diffs = torch.norm(pred - dmp_tensor_unsqueezed, dim=-1)
    diffs = diffs.squeeze(1)
    
    weights = torch.ones_like(diffs)
    if diffs.shape[0] > 0:
        weights[0] = weight_edge
        if diffs.shape[0] > 1:
            weights[-1] = weight_edge
    
    loss = torch.sum(weights * diffs)
    return loss

def loss_to_score(loss_tensor, scaling_factor):
   
    return torch.exp(-loss_tensor * scaling_factor)


def scoring_function(trajectory_np, dmp_trajectory_np):
    
    pred = torch.tensor(trajectory_np, dtype=torch.float32).unsqueeze(1)
    dmp_trajectory = torch.tensor(dmp_trajectory_np, dtype=torch.float32)

    smooth_loss = smoothness_loss(pred)
    closed_loss = closed_shape_loss(pred)
    sym_loss = symmetry_loss(pred)
    shape_pres_loss = shape_preservation_loss(pred, dmp_trajectory)
    
    smooth_score = loss_to_score(smooth_loss, scaling_factor=0.01)
    closed_score = loss_to_score(closed_loss, scaling_factor=1.0)
    sym_score = loss_to_score(sym_loss, scaling_factor=1.0)
    shape_pres_score = loss_to_score(shape_pres_loss, scaling_factor=0.001)

    # Calculate the final score as a weighted average of the individual scores
    final_score = (0.03 * smooth_score +
                   0.03 * closed_score +
                   0.03 * sym_score +
                   0.9 * shape_pres_score)

    return {
        # Return the raw losses
        'smoothness_loss': smooth_loss.item(),
        'closed_shape_loss': closed_loss.item(),
        'symmetry_loss': sym_loss.item(),
        'shape_preservation_loss': shape_pres_loss.item(),
        
        # Return the single, normalized final score
        'final_score': final_score.item(),
    }

def process_rollouts(rollouts_file_path, dmp_ref_path):
    # 1. Load the rollout and DMP trajectories
    try:
        all_trajectories = np.load(rollouts_file_path, allow_pickle=True)
        if isinstance(all_trajectories, np.ndarray) and all_trajectories.ndim == 0:
            all_trajectories = all_trajectories.item()
        if isinstance(all_trajectories, dict):
            trajectories = all_trajectories.get('rollouts', [])
        elif isinstance(all_trajectories, (list, np.ndarray)):
            trajectories = all_trajectories
        else:
            raise TypeError("Loaded data is not a recognized trajectory format.")
    except FileNotFoundError:
        print(f"Error: The file '{rollouts_file_path}' was not found.")
        return None
    except Exception as e:
        print(f"An error occurred while loading the rollouts file: {e}")
        return None
    if not isinstance(trajectories, (list, np.ndarray)) or len(trajectories) == 0:
        print("No valid trajectories found to process.")
        return None
    
    # 2. Determine sequence_length and load DMP
    try:
        if isinstance(trajectories[0], dict):
            sequence_length = trajectories[0]['states'].shape[0]
        else:
            sequence_length = trajectories[0].shape[0]
        if sequence_length == 0:
            print("Trajectories are empty or have zero length.")
            return None
    except (IndexError, KeyError, AttributeError) as e:
        print(f"Error determining trajectory length from the first element: {e}")
        return None
    try:
        dmp_trajectory_np = np.load(dmp_ref_path)
        if dmp_trajectory_np.shape != (sequence_length, 2):
            raise ValueError(f"DMP trajectory shape {dmp_trajectory_np.shape} does not match rollout trajectory length {sequence_length}.")
        print(f"Loaded DMP reference trajectory of shape {dmp_trajectory_np.shape}")
    except FileNotFoundError:
        print(f"Error: The DMP reference file '{dmp_ref_path}' was not found.")
        return None
    except Exception as e:
        print(f"An error occurred while loading the DMP reference file: {e}")
        return None

    print("\n--- Processing trajectories (single pass) ---")
    all_results = []
    for i, trajectory in enumerate(trajectories):
        try:
            if isinstance(trajectory, dict):
                trajectory_np = np.asarray(trajectory['states'], dtype=np.float32)
            else:
                trajectory_np = np.asarray(trajectory, dtype=np.float32)
            if trajectory_np.shape != (sequence_length, 2):
                print(f"Warning: Trajectory {i+1} has unexpected shape {trajectory_np.shape}. Skipping.")
                continue
            score = scoring_function(trajectory_np, dmp_trajectory_np)
            all_results.append(score)
            print(f"Trajectory {i+1}/{len(trajectories)} processed. Results: {score}")
        except (KeyError, AttributeError) as e:
            print(f"Error processing trajectory {i+1} from a dictionary: {e}. Skipping.")
            continue
        except Exception as e:
            print(f"An unexpected error occurred while processing trajectory {i+1}: {e}. Skipping.")
            continue

    if not all_results:
        print("No trajectories were successfully processed.")
        return None

    all_keys = set().union(*(d.keys() for d in all_results))
    final_stats = {}
    for key in all_keys:
        values = [d[key] for d in all_results if key in d]
        if values:
            np_values = np.array(values)
            mean_value = np.mean(np_values)
            std_value = np.std(np_values)
            final_stats[f'{key}_mean'] = mean_value
            final_stats[f'{key}_std'] = std_value
    return final_stats

if __name__ == "__main__":
    rollouts_file_path = '/path to /cleaned rollouts.npy'
    dmp_ref_path = '/path to //dmp_ref.npy'

    results = process_rollouts(rollouts_file_path, dmp_ref_path)
    if results:
        print("\n--- Final Results ---")
        for key, value in results.items():
            print(f"{key:<30}: {value:.6f}")
    else:
        print("Could not generate final results.")
# Out:
# Loaded DMP reference trajectory of shape (60, 2)
#
# --- Processing trajectories (single pass) ---
# Trajectory 1/50 processed. Results: {'smoothness_loss': 0.42193442583084106, 'closed_shape_loss': 8.36997127532959, 'symmetry_loss': 0.19896899163722992, 'shape_preservation_loss': 20.547687530517578, 'final_score': 0.9361637234687805}
# Trajectory 2/50 processed. Results: {'smoothness_loss': 0.556073009967804, 'closed_shape_loss': 11.758636474609375, 'symmetry_loss': 0.09529297798871994, 'shape_preservation_loss': 39.2220458984375, 'final_score': 0.9224905371665955}
# Trajectory 3/50 processed. Results: {'smoothness_loss': 0.6836568117141724, 'closed_shape_loss': 12.190058708190918, 'symmetry_loss': 0.11868909746408463, 'shape_preservation_loss': 42.28376770019531, 'final_score': 0.9191762208938599}
# Trajectory 4/50 processed. Results: {'smoothness_loss': 0.026881588622927666, 'closed_shape_loss': 4.99674129486084, 'symmetry_loss': 0.14042988419532776, 'shape_preservation_loss': 44.18309020996094, 'final_score': 0.9173651337623596}
# Trajectory 5/50 processed. Results: {'smoothness_loss': 0.035371046513319016, 'closed_shape_loss': 4.619389533996582, 'symmetry_loss': 0.12360278517007828, 'shape_preservation_loss': 39.75407409667969, 'final_score': 0.9217202663421631}
# Trajectory 6/50 processed. Results: {'smoothness_loss': 0.433139830827713, 'closed_shape_loss': 11.224708557128906, 'symmetry_loss': 0.1525816023349762, 'shape_preservation_loss': 67.94998168945312, 'final_score': 0.8965018391609192}
# Trajectory 7/50 processed. Results: {'smoothness_loss': 0.41723117232322693, 'closed_shape_loss': 8.791085243225098, 'symmetry_loss': 0.1664775311946869, 'shape_preservation_loss': 19.388586044311523, 'final_score': 0.9379972219467163}
# Trajectory 8/50 processed. Results: {'smoothness_loss': 0.41115429997444153, 'closed_shape_loss': 7.724088191986084, 'symmetry_loss': 0.1851348876953125, 'shape_preservation_loss': 28.199262619018555, 'final_score': 0.9297950863838196}
# Trajectory 9/50 processed. Results: {'smoothness_loss': 0.028203299269080162, 'closed_shape_loss': 4.962591648101807, 'symmetry_loss': 0.1301722526550293, 'shape_preservation_loss': 42.590457916259766, 'final_score': 0.9190130829811096}
# Trajectory 10/50 processed. Results: {'smoothness_loss': 0.5387656688690186, 'closed_shape_loss': 11.723224639892578, 'symmetry_loss': 0.10496209561824799, 'shape_preservation_loss': 39.85390090942383, 'final_score': 0.9216866493225098}
# Trajectory 11/50 processed. Results: {'smoothness_loss': 0.7165471315383911, 'closed_shape_loss': 12.18038558959961, 'symmetry_loss': 0.1288783997297287, 'shape_preservation_loss': 43.07350540161133, 'final_score': 0.9182152152061462}
# Trajectory 12/50 processed. Results: {'smoothness_loss': 0.4269464910030365, 'closed_shape_loss': 8.361751556396484, 'symmetry_loss': 0.17585128545761108, 'shape_preservation_loss': 20.493410110473633, 'final_score': 0.936785101890564}
# Trajectory 13/50 processed. Results: {'smoothness_loss': 0.5374798774719238, 'closed_shape_loss': 11.78160285949707, 'symmetry_loss': 0.10783804953098297, 'shape_preservation_loss': 40.454898834228516, 'final_score': 0.9210898280143738}
# Trajectory 14/50 processed. Results: {'smoothness_loss': 0.4315693974494934, 'closed_shape_loss': 8.38016128540039, 'symmetry_loss': 0.1720888465642929, 'shape_preservation_loss': 23.219886779785156, 'final_score': 0.934477686882019}
# Trajectory 15/50 processed. Results: {'smoothness_loss': 0.03069019876420498, 'closed_shape_loss': 4.806105613708496, 'symmetry_loss': 0.11862921714782715, 'shape_preservation_loss': 41.165809631347656, 'final_score': 0.9205833077430725}
# Trajectory 16/50 processed. Results: {'smoothness_loss': 0.03566945344209671, 'closed_shape_loss': 4.577193737030029, 'symmetry_loss': 0.12465303391218185, 'shape_preservation_loss': 40.247901916503906, 'final_score': 0.9212779998779297}
# Trajectory 17/50 processed. Results: {'smoothness_loss': 0.027407117187976837, 'closed_shape_loss': 5.085784912109375, 'symmetry_loss': 0.14149144291877747, 'shape_preservation_loss': 45.847259521484375, 'final_score': 0.9158881902694702}
# Trajectory 18/50 processed. Results: {'smoothness_loss': 0.738469123840332, 'closed_shape_loss': 12.334704399108887, 'symmetry_loss': 0.14276477694511414, 'shape_preservation_loss': 44.263946533203125, 'final_score': 0.9168193936347961}
# Trajectory 19/50 processed. Results: {'smoothness_loss': 0.40415945649147034, 'closed_shape_loss': 8.41889762878418, 'symmetry_loss': 0.16672120988368988, 'shape_preservation_loss': 18.67567253112793, 'final_score': 0.9386265277862549}
# Trajectory 20/50 processed. Results: {'smoothness_loss': 0.5322198867797852, 'closed_shape_loss': 11.74658203125, 'symmetry_loss': 0.10942021012306213, 'shape_preservation_loss': 40.166778564453125, 'final_score': 0.9212978482246399}
# Trajectory 21/50 processed. Results: {'smoothness_loss': 0.4536299705505371, 'closed_shape_loss': 11.412393569946289, 'symmetry_loss': 0.1433504968881607, 'shape_preservation_loss': 63.051692962646484, 'final_score': 0.9008634686470032}
# Trajectory 22/50 processed. Results: {'smoothness_loss': 0.4954755902290344, 'closed_shape_loss': 11.586431503295898, 'symmetry_loss': 0.12440796196460724, 'shape_preservation_loss': 41.20201873779297, 'final_score': 0.9200143218040466}
# Trajectory 23/50 processed. Results: {'smoothness_loss': 0.5833401083946228, 'closed_shape_loss': 11.899234771728516, 'symmetry_loss': 0.09818104654550552, 'shape_preservation_loss': 40.14030838012695, 'final_score': 0.9216094017028809}
# Trajectory 24/50 processed. Results: {'smoothness_loss': 0.43362388014793396, 'closed_shape_loss': 8.473806381225586, 'symmetry_loss': 0.18293938040733337, 'shape_preservation_loss': 20.583890914916992, 'final_score': 0.9365248680114746}
# Trajectory 25/50 processed. Results: {'smoothness_loss': 0.024092035368084908, 'closed_shape_loss': 5.194812774658203, 'symmetry_loss': 0.1710803359746933, 'shape_preservation_loss': 53.27545166015625, 'final_score': 0.9087486267089844}
# Trajectory 26/50 processed. Results: {'smoothness_loss': 0.5171382427215576, 'closed_shape_loss': 11.708539962768555, 'symmetry_loss': 0.10240752249956131, 'shape_preservation_loss': 40.236629486083984, 'final_score': 0.9214312434196472}
# Trajectory 27/50 processed. Results: {'smoothness_loss': 0.39730343222618103, 'closed_shape_loss': 8.184284210205078, 'symmetry_loss': 0.16720980405807495, 'shape_preservation_loss': 19.780532836914062, 'final_score': 0.9376424551010132}
# Trajectory 28/50 processed. Results: {'smoothness_loss': 0.02768861874938011, 'closed_shape_loss': 4.957169055938721, 'symmetry_loss': 0.15106691420078278, 'shape_preservation_loss': 44.328975677490234, 'final_score': 0.9169715642929077}
# Trajectory 29/50 processed. Results: {'smoothness_loss': 0.41666847467422485, 'closed_shape_loss': 7.971527576446533, 'symmetry_loss': 0.18364009261131287, 'shape_preservation_loss': 21.94072723388672, 'final_score': 0.9353210926055908}
# Trajectory 30/50 processed. Results: {'smoothness_loss': 0.03527374565601349, 'closed_shape_loss': 4.502389907836914, 'symmetry_loss': 0.12420420348644257, 'shape_preservation_loss': 40.85969161987305, 'final_score': 0.9207853078842163}
# Trajectory 31/50 processed. Results: {'smoothness_loss': 0.028861086815595627, 'closed_shape_loss': 4.885092735290527, 'symmetry_loss': 0.12769950926303864, 'shape_preservation_loss': 41.473731994628906, 'final_score': 0.9200586676597595}
# Trajectory 32/50 processed. Results: {'smoothness_loss': 0.4100193977355957, 'closed_shape_loss': 8.603713989257812, 'symmetry_loss': 0.1696988046169281, 'shape_preservation_loss': 18.902374267578125, 'final_score': 0.9383479356765747}
# Trajectory 33/50 processed. Results: {'smoothness_loss': 0.48636922240257263, 'closed_shape_loss': 11.467083930969238, 'symmetry_loss': 0.1350249946117401, 'shape_preservation_loss': 40.67067337036133, 'final_score': 0.9201962947845459}
# Trajectory 34/50 processed. Results: {'smoothness_loss': 0.8741555213928223, 'closed_shape_loss': 12.886409759521484, 'symmetry_loss': 0.18196114897727966, 'shape_preservation_loss': 54.03652572631836, 'final_score': 0.90740567445755}
# Trajectory 35/50 processed. Results: {'smoothness_loss': 0.02243165299296379, 'closed_shape_loss': 5.365781307220459, 'symmetry_loss': 0.17137619853019714, 'shape_preservation_loss': 56.591957092285156, 'final_score': 0.9058902263641357}
# Trajectory 36/50 processed. Results: {'smoothness_loss': 0.020204156637191772, 'closed_shape_loss': 5.708889007568359, 'symmetry_loss': 0.1528722494840622, 'shape_preservation_loss': 64.19865417480469, 'final_score': 0.8998773694038391}
# Trajectory 37/50 processed. Results: {'smoothness_loss': 0.40780216455459595, 'closed_shape_loss': 8.536955833435059, 'symmetry_loss': 0.17275139689445496, 'shape_preservation_loss': 18.796367645263672, 'final_score': 0.9383654594421387}
# Trajectory 38/50 processed. Results: {'smoothness_loss': 0.7323246598243713, 'closed_shape_loss': 12.195115089416504, 'symmetry_loss': 0.12943996489048004, 'shape_preservation_loss': 44.88093566894531, 'final_score': 0.9166390299797058}
# Trajectory 39/50 processed. Results: {'smoothness_loss': 0.4176512360572815, 'closed_shape_loss': 8.595192909240723, 'symmetry_loss': 0.15965868532657623, 'shape_preservation_loss': 19.289546966552734, 'final_score': 0.9382592439651489}
# Trajectory 40/50 processed. Results: {'smoothness_loss': 0.8286375403404236, 'closed_shape_loss': 12.639312744140625, 'symmetry_loss': 0.1711755245923996, 'shape_preservation_loss': 50.99283981323242, 'final_score': 0.9102896451950073}
# Trajectory 41/50 processed. Results: {'smoothness_loss': 0.7134367227554321, 'closed_shape_loss': 12.200572967529297, 'symmetry_loss': 0.12815776467323303, 'shape_preservation_loss': 42.90156936645508, 'final_score': 0.9183834195137024}
# Trajectory 42/50 processed. Results: {'smoothness_loss': 0.43507662415504456, 'closed_shape_loss': 8.525392532348633, 'symmetry_loss': 0.17688094079494476, 'shape_preservation_loss': 20.280921936035156, 'final_score': 0.9369431138038635}
# Trajectory 43/50 processed. Results: {'smoothness_loss': 0.024846170097589493, 'closed_shape_loss': 5.169907569885254, 'symmetry_loss': 0.15880942344665527, 'shape_preservation_loss': 51.336612701416016, 'final_score': 0.9107208251953125}
# Trajectory 44/50 processed. Results: {'smoothness_loss': 0.026692604646086693, 'closed_shape_loss': 4.99757719039917, 'symmetry_loss': 0.14158353209495544, 'shape_preservation_loss': 44.331764221191406, 'final_score': 0.9172070026397705}
# Trajectory 45/50 processed. Results: {'smoothness_loss': 0.7616345882415771, 'closed_shape_loss': 12.261728286743164, 'symmetry_loss': 0.14838285744190216, 'shape_preservation_loss': 46.1799201965332, 'final_score': 0.9150186777114868}
# Trajectory 46/50 processed. Results: {'smoothness_loss': 0.41524767875671387, 'closed_shape_loss': 7.764863014221191, 'symmetry_loss': 0.1898561269044876, 'shape_preservation_loss': 27.677705764770508, 'final_score': 0.9301323294639587}
# Trajectory 47/50 processed. Results: {'smoothness_loss': 0.019022328779101372, 'closed_shape_loss': 5.90278959274292, 'symmetry_loss': 0.13814711570739746, 'shape_preservation_loss': 68.29234313964844, 'final_score': 0.8967939615249634}
# Trajectory 48/50 processed. Results: {'smoothness_loss': 0.6598227620124817, 'closed_shape_loss': 12.149190902709961, 'symmetry_loss': 0.11481581628322601, 'shape_preservation_loss': 41.81766891479492, 'final_score': 0.9196889400482178}
# Trajectory 49/50 processed. Results: {'smoothness_loss': 0.4247959852218628, 'closed_shape_loss': 8.741024017333984, 'symmetry_loss': 0.18514250218868256, 'shape_preservation_loss': 20.101585388183594, 'final_score': 0.9368963241577148}
# Trajectory 50/50 processed. Results: {'smoothness_loss': 0.4201316833496094, 'closed_shape_loss': 8.915122032165527, 'symmetry_loss': 0.16750937700271606, 'shape_preservation_loss': 19.808494567871094, 'final_score': 0.9375990033149719}
#
# --- Final Results ---
# smoothness_loss_mean          : 0.378939
# smoothness_loss_std           : 0.257859
# final_score_mean              : 0.922032
# final_score_std               : 0.011634
# symmetry_loss_mean            : 0.147482
# symmetry_loss_std             : 0.027219
# closed_shape_loss_mean        : 8.748719
# closed_shape_loss_std         : 2.867254
# shape_preservation_loss_mean  : 38.390881
# shape_preservation_loss_std   : 13.795624

# %% [markdown]
# NOISY

# %%
import numpy as np
import torch

def smoothness_loss(pred):
    
    dx = torch.diff(pred[:, :, 0], dim=0)
    dy = torch.diff(pred[:, :, 1], dim=0)
    d1 = dx**2 + dy**2
    loss_d1 = torch.sum(d1)
    
    ddx = torch.diff(dx, dim=0)
    ddy = torch.diff(dy, dim=0)
    d2 = ddx**2 + ddy**2
    loss_d2 = torch.sum(d2)
    
    dddx = torch.diff(ddx, dim=0)
    dddy = torch.diff(ddy, dim=0)
    d3 = dddx**2 + dddy**2
    loss_d3 = torch.sum(d3)
    
    loss = 0.2 * loss_d1 + 0.3 * loss_d2 + 0.5 * loss_d3
    
    return loss
 
def closed_shape_loss(pred):
   
    return torch.norm(pred[:,:,0] - pred[:,:,-1])
 
def symmetry_loss(pred):
    
    pred_squeezed = pred.squeeze(1) 
    centroid = torch.mean(pred_squeezed, dim=0)
    reflected_x = 2 * centroid[0] - pred_squeezed[:, 0]
    reflected_points = torch.stack((reflected_x, pred_squeezed[:, 1]), dim=1)
    
    diff = reflected_points[:, None, :] - pred_squeezed[None, :, :]
    dists = torch.norm(diff, dim=2)
    min_dists, _ = torch.min(dists, dim=1)
    
    return torch.mean(min_dists)
 
def shape_preservation_loss(pred, dmp_trajectory, weight_edge=1):
    
    dmp_tensor_unsqueezed = dmp_trajectory.unsqueeze(1)
    diffs = torch.norm(pred - dmp_tensor_unsqueezed, dim=-1)
    diffs = diffs.squeeze(1)
    
    weights = torch.ones_like(diffs)
    if diffs.shape[0] > 0:
        weights[0] = weight_edge
        if diffs.shape[0] > 1:
            weights[-1] = weight_edge
    
    loss = torch.sum(weights * diffs)
    return loss

# --- Helper Function to Normalize Losses to Scores (Robust Method) ---

def loss_to_score(loss_tensor, scaling_factor):
    
    return torch.exp(-loss_tensor * scaling_factor)

# --- Scoring Function (Modified to return raw losses and one final score) ---

def scoring_function(trajectory_np, dmp_trajectory_np):
    
    pred = torch.tensor(trajectory_np, dtype=torch.float32).unsqueeze(1)
    dmp_trajectory = torch.tensor(dmp_trajectory_np, dtype=torch.float32)

    # 1. Calculate raw losses
    smooth_loss = smoothness_loss(pred)
    closed_loss = closed_shape_loss(pred)
    sym_loss = symmetry_loss(pred)
    shape_pres_loss = shape_preservation_loss(pred, dmp_trajectory)
    
    # 2. Convert raw losses to scores (0 to 1) for final score calculation
    smooth_score = loss_to_score(smooth_loss, scaling_factor=0.01)
    closed_score = loss_to_score(closed_loss, scaling_factor=1.0)
    sym_score = loss_to_score(sym_loss, scaling_factor=1.0)
    shape_pres_score = loss_to_score(shape_pres_loss, scaling_factor=0.001)

    # 3. Calculate the final score as a weighted average of the individual scores
    final_score = (0.03 * smooth_score +
                   0.03 * closed_score +
                   0.03 * sym_score +
                   0.9 * shape_pres_score)

    return {
        # Return the raw losses
        'smoothness_loss': smooth_loss.item(),
        'closed_shape_loss': closed_loss.item(),
        'symmetry_loss': sym_loss.item(),
        'shape_preservation_loss': shape_pres_loss.item(),
        
        # Return the single, normalized final score
        'final_score': final_score.item(),
    }

# --- Main processing logic ---

def process_rollouts(rollouts_file_path, dmp_ref_path):
   
    # 1. Load the rollout and DMP trajectories
    try:
        all_trajectories = np.load(rollouts_file_path, allow_pickle=True)
        if isinstance(all_trajectories, np.ndarray) and all_trajectories.ndim == 0:
            all_trajectories = all_trajectories.item()
        if isinstance(all_trajectories, dict):
            trajectories = all_trajectories.get('rollouts', [])
        elif isinstance(all_trajectories, (list, np.ndarray)):
            trajectories = all_trajectories
        else:
            raise TypeError("Loaded data is not a recognized trajectory format.")
    except FileNotFoundError:
        print(f"Error: The file '{rollouts_file_path}' was not found.")
        return None
    except Exception as e:
        print(f"An error occurred while loading the rollouts file: {e}")
        return None
    if not isinstance(trajectories, (list, np.ndarray)) or len(trajectories) == 0:
        print("No valid trajectories found to process.")
        return None
    
    # 2. Determine sequence_length and load DMP
    try:
        if isinstance(trajectories[0], dict):
            sequence_length = trajectories[0]['states'].shape[0]
        else:
            sequence_length = trajectories[0].shape[0]
        if sequence_length == 0:
            print("Trajectories are empty or have zero length.")
            return None
    except (IndexError, KeyError, AttributeError) as e:
        print(f"Error determining trajectory length from the first element: {e}")
        return None
    try:
        dmp_trajectory_np = np.load(dmp_ref_path)
        if dmp_trajectory_np.shape != (sequence_length, 2):
            raise ValueError(f"DMP trajectory shape {dmp_trajectory_np.shape} does not match rollout trajectory length {sequence_length}.")
        print(f"Loaded DMP reference trajectory of shape {dmp_trajectory_np.shape}")
    except FileNotFoundError:
        print(f"Error: The DMP reference file '{dmp_ref_path}' was not found.")
        return None
    except Exception as e:
        print(f"An error occurred while loading the DMP reference file: {e}")
        return None

    # --- Single Pass: Compute Scores and Collect Results ---
    print("\n--- Processing trajectories (single pass) ---")
    all_results = []
    for i, trajectory in enumerate(trajectories):
        try:
            if isinstance(trajectory, dict):
                trajectory_np = np.asarray(trajectory['states'], dtype=np.float32)
            else:
                trajectory_np = np.asarray(trajectory, dtype=np.float32)
            if trajectory_np.shape != (sequence_length, 2):
                print(f"Warning: Trajectory {i+1} has unexpected shape {trajectory_np.shape}. Skipping.")
                continue
            score = scoring_function(trajectory_np, dmp_trajectory_np)
            all_results.append(score)
            print(f"Trajectory {i+1}/{len(trajectories)} processed. Results: {score}")
        except (KeyError, AttributeError) as e:
            print(f"Error processing trajectory {i+1} from a dictionary: {e}. Skipping.")
            continue
        except Exception as e:
            print(f"An unexpected error occurred while processing trajectory {i+1}: {e}. Skipping.")
            continue

    if not all_results:
        print("No trajectories were successfully processed.")
        return None

    all_keys = set().union(*(d.keys() for d in all_results))
    final_stats = {}
    for key in all_keys:
        values = [d[key] for d in all_results if key in d]
        if values:
            np_values = np.array(values)
            mean_value = np.mean(np_values)
            std_value = np.std(np_values)
            final_stats[f'{key}_mean'] = mean_value
            final_stats[f'{key}_std'] = std_value
    return final_stats


if __name__ == "__main__":
    rollouts_file_path = '/path/to/noisy rollouts.npy'
    dmp_ref_path = '/path to/dmp_ref.npy'

    results = process_rollouts(rollouts_file_path, dmp_ref_path)
    if results:
        print("\n--- Final Results ---")
        for key, value in results.items():
            print(f"{key:<30}: {value:.6f}")
    else:
        print("Could not generate final results.")
# Out:
# Loaded DMP reference trajectory of shape (60, 2)
#
# --- Processing trajectories (single pass) ---
# Trajectory 1/50 processed. Results: {'smoothness_loss': 0.254970908164978, 'closed_shape_loss': 12.832009315490723, 'symmetry_loss': 0.7702195048332214, 'shape_preservation_loss': 117.12025451660156, 'final_score': 0.8443413972854614}
# Trajectory 2/50 processed. Results: {'smoothness_loss': 0.1480376422405243, 'closed_shape_loss': 10.889790534973145, 'symmetry_loss': 0.4178933799266815, 'shape_preservation_loss': 112.12327575683594, 'final_score': 0.8542497754096985}
# Trajectory 3/50 processed. Results: {'smoothness_loss': 0.3829572796821594, 'closed_shape_loss': 13.089766502380371, 'symmetry_loss': 0.4208792746067047, 'shape_preservation_loss': 115.92396545410156, 'final_score': 0.8510681390762329}
# Trajectory 4/50 processed. Results: {'smoothness_loss': 0.48987966775894165, 'closed_shape_loss': 12.73538589477539, 'symmetry_loss': 1.2576298713684082, 'shape_preservation_loss': 117.20185852050781, 'final_score': 0.838848352432251}
# Trajectory 5/50 processed. Results: {'smoothness_loss': 0.5750091075897217, 'closed_shape_loss': 13.181060791015625, 'symmetry_loss': 1.4311147928237915, 'shape_preservation_loss': 125.25837707519531, 'final_score': 0.8310413360595703}
# Trajectory 6/50 processed. Results: {'smoothness_loss': 0.15498757362365723, 'closed_shape_loss': 11.18178653717041, 'symmetry_loss': 0.46575841307640076, 'shape_preservation_loss': 113.10580444335938, 'final_score': 0.8525342345237732}
# Trajectory 7/50 processed. Results: {'smoothness_loss': 0.1608448177576065, 'closed_shape_loss': 6.465163707733154, 'symmetry_loss': 0.15555988252162933, 'shape_preservation_loss': 73.0039291381836, 'final_score': 0.8923140168190002}
# Trajectory 8/50 processed. Results: {'smoothness_loss': 0.37303128838539124, 'closed_shape_loss': 12.34013557434082, 'symmetry_loss': 0.666113555431366, 'shape_preservation_loss': 109.2716064453125, 'final_score': 0.8521376252174377}
# Trajectory 9/50 processed. Results: {'smoothness_loss': 0.4433635175228119, 'closed_shape_loss': 12.542917251586914, 'symmetry_loss': 1.0972964763641357, 'shape_preservation_loss': 113.48501586914062, 'final_score': 0.8433263301849365}
# Trajectory 10/50 processed. Results: {'smoothness_loss': 0.20539605617523193, 'closed_shape_loss': 12.533989906311035, 'symmetry_loss': 0.7070544362068176, 'shape_preservation_loss': 116.71168518066406, 'final_score': 0.8455888628959656}
# Trajectory 11/50 processed. Results: {'smoothness_loss': 0.4670928418636322, 'closed_shape_loss': 12.636343002319336, 'symmetry_loss': 1.2864413261413574, 'shape_preservation_loss': 115.20704650878906, 'final_score': 0.8402112722396851}
# Trajectory 12/50 processed. Results: {'smoothness_loss': 0.4127976596355438, 'closed_shape_loss': 12.367120742797852, 'symmetry_loss': 1.1223801374435425, 'shape_preservation_loss': 110.47441864013672, 'final_score': 0.845509946346283}
# Trajectory 13/50 processed. Results: {'smoothness_loss': 0.18928422033786774, 'closed_shape_loss': 12.233208656311035, 'symmetry_loss': 0.6510080695152283, 'shape_preservation_loss': 115.96426391601562, 'final_score': 0.847045361995697}
# Trajectory 14/50 processed. Results: {'smoothness_loss': 0.36942845582962036, 'closed_shape_loss': 13.20187759399414, 'symmetry_loss': 0.6348616480827332, 'shape_preservation_loss': 117.0903549194336, 'final_score': 0.846343994140625}
# Trajectory 15/50 processed. Results: {'smoothness_loss': 0.3725448548793793, 'closed_shape_loss': 12.300153732299805, 'symmetry_loss': 0.8336989283561707, 'shape_preservation_loss': 108.45580291748047, 'final_score': 0.8504184484481812}
# Trajectory 16/50 processed. Results: {'smoothness_loss': 0.16312792897224426, 'closed_shape_loss': 5.637994289398193, 'symmetry_loss': 0.16619287431240082, 'shape_preservation_loss': 55.022029876708984, 'final_score': 0.9072822332382202}
# Trajectory 17/50 processed. Results: {'smoothness_loss': 0.549023449420929, 'closed_shape_loss': 12.987689018249512, 'symmetry_loss': 1.4351725578308105, 'shape_preservation_loss': 122.37069702148438, 'final_score': 0.8333163261413574}
# Trajectory 18/50 processed. Results: {'smoothness_loss': 0.13868550956249237, 'closed_shape_loss': 10.323838233947754, 'symmetry_loss': 0.35099518299102783, 'shape_preservation_loss': 110.21614074707031, 'final_score': 0.8571555018424988}
# Trajectory 19/50 processed. Results: {'smoothness_loss': 0.4417791962623596, 'closed_shape_loss': 12.513298034667969, 'symmetry_loss': 1.089123249053955, 'shape_preservation_loss': 113.14897918701172, 'final_score': 0.8436790108680725}
# Trajectory 20/50 processed. Results: {'smoothness_loss': 0.34903156757354736, 'closed_shape_loss': 13.163865089416504, 'symmetry_loss': 0.7467389702796936, 'shape_preservation_loss': 116.79999542236328, 'final_score': 0.844899594783783}
# Trajectory 21/50 processed. Results: {'smoothness_loss': 0.3558538854122162, 'closed_shape_loss': 13.17292308807373, 'symmetry_loss': 0.6779184937477112, 'shape_preservation_loss': 116.6820068359375, 'final_score': 0.8460050225257874}
# Trajectory 22/50 processed. Results: {'smoothness_loss': 0.3950819969177246, 'closed_shape_loss': 13.028666496276855, 'symmetry_loss': 0.39851507544517517, 'shape_preservation_loss': 115.63156127929688, 'final_score': 0.8517442345619202}
# Trajectory 23/50 processed. Results: {'smoothness_loss': 0.3386766016483307, 'closed_shape_loss': 13.184117317199707, 'symmetry_loss': 0.7906668782234192, 'shape_preservation_loss': 117.44381713867188, 'final_score': 0.843776285648346}
# Trajectory 24/50 processed. Results: {'smoothness_loss': 0.14302076399326324, 'closed_shape_loss': 10.667072296142578, 'symmetry_loss': 0.38592204451560974, 'shape_preservation_loss': 111.70487976074219, 'final_score': 0.8552298545837402}
# Trajectory 25/50 processed. Results: {'smoothness_loss': 0.1574578583240509, 'closed_shape_loss': 11.286858558654785, 'symmetry_loss': 0.4744054079055786, 'shape_preservation_loss': 113.677978515625, 'final_score': 0.8519116044044495}
# Trajectory 26/50 processed. Results: {'smoothness_loss': 0.3161907196044922, 'closed_shape_loss': 13.100287437438965, 'symmetry_loss': 0.8226519227027893, 'shape_preservation_loss': 117.66806030273438, 'final_score': 0.8431752920150757}
# Trajectory 27/50 processed. Results: {'smoothness_loss': 0.29751044511795044, 'closed_shape_loss': 13.00580883026123, 'symmetry_loss': 0.8016722202301025, 'shape_preservation_loss': 117.68450164794922, 'final_score': 0.8434470891952515}
# Trajectory 28/50 processed. Results: {'smoothness_loss': 0.1654198169708252, 'closed_shape_loss': 11.570260047912598, 'symmetry_loss': 0.5174388885498047, 'shape_preservation_loss': 114.62031555175781, 'final_score': 0.8503662347793579}
# Trajectory 29/50 processed. Results: {'smoothness_loss': 0.14736393094062805, 'closed_shape_loss': 10.89416217803955, 'symmetry_loss': 0.4129144549369812, 'shape_preservation_loss': 112.38644409179688, 'final_score': 0.8541368842124939}
# Trajectory 30/50 processed. Results: {'smoothness_loss': 0.1688266396522522, 'closed_shape_loss': 6.19865083694458, 'symmetry_loss': 0.1617397964000702, 'shape_preservation_loss': 69.41372680664062, 'final_score': 0.8951767683029175}
# Trajectory 31/50 processed. Results: {'smoothness_loss': 0.3383163809776306, 'closed_shape_loss': 13.187010765075684, 'symmetry_loss': 0.7842480540275574, 'shape_preservation_loss': 117.64702606201172, 'final_score': 0.8437014222145081}
# Trajectory 32/50 processed. Results: {'smoothness_loss': 0.559858500957489, 'closed_shape_loss': 13.083601951599121, 'symmetry_loss': 1.4454659223556519, 'shape_preservation_loss': 123.69462585449219, 'final_score': 0.8321863412857056}
# Trajectory 33/50 processed. Results: {'smoothness_loss': 0.4433180093765259, 'closed_shape_loss': 12.647176742553711, 'symmetry_loss': 1.1320865154266357, 'shape_preservation_loss': 114.16844177246094, 'final_score': 0.8424350619316101}
# Trajectory 34/50 processed. Results: {'smoothness_loss': 0.28013285994529724, 'closed_shape_loss': 7.049200057983398, 'symmetry_loss': 0.14183005690574646, 'shape_preservation_loss': 25.25033950805664, 'final_score': 0.9335343837738037}
# Trajectory 35/50 processed. Results: {'smoothness_loss': 0.4798088073730469, 'closed_shape_loss': 12.71572208404541, 'symmetry_loss': 1.2825467586517334, 'shape_preservation_loss': 116.45022583007812, 'final_score': 0.8392433524131775}
# Trajectory 36/50 processed. Results: {'smoothness_loss': 0.21862483024597168, 'closed_shape_loss': 12.67580509185791, 'symmetry_loss': 0.7442750334739685, 'shape_preservation_loss': 116.5833511352539, 'final_score': 0.8451472520828247}
# Trajectory 37/50 processed. Results: {'smoothness_loss': 0.2988743782043457, 'closed_shape_loss': 12.991153717041016, 'symmetry_loss': 0.8170056939125061, 'shape_preservation_loss': 117.15498352050781, 'final_score': 0.8436657190322876}
# Trajectory 38/50 processed. Results: {'smoothness_loss': 0.2580264210700989, 'closed_shape_loss': 12.851570129394531, 'symmetry_loss': 0.786514163017273, 'shape_preservation_loss': 116.87298583984375, 'final_score': 0.8443140387535095}
# Trajectory 39/50 processed. Results: {'smoothness_loss': 0.21658675372600555, 'closed_shape_loss': 12.687121391296387, 'symmetry_loss': 0.7200899720191956, 'shape_preservation_loss': 117.30055236816406, 'final_score': 0.8449225425720215}
# Trajectory 40/50 processed. Results: {'smoothness_loss': 0.15846091508865356, 'closed_shape_loss': 11.261475563049316, 'symmetry_loss': 0.49058398604393005, 'shape_preservation_loss': 112.99695587158203, 'final_score': 0.8521589636802673}
# Trajectory 41/50 processed. Results: {'smoothness_loss': 0.1575794368982315, 'closed_shape_loss': 11.224262237548828, 'symmetry_loss': 0.48706942796707153, 'shape_preservation_loss': 112.75305938720703, 'final_score': 0.8524199724197388}
# Trajectory 42/50 processed. Results: {'smoothness_loss': 0.17675161361694336, 'closed_shape_loss': 11.912714958190918, 'symmetry_loss': 0.5827834010124207, 'shape_preservation_loss': 115.4333724975586, 'final_score': 0.8485794067382812}
# Trajectory 43/50 processed. Results: {'smoothness_loss': 0.29637014865875244, 'closed_shape_loss': 12.975472450256348, 'symmetry_loss': 0.787894070148468, 'shape_preservation_loss': 117.69367980957031, 'final_score': 0.8436267375946045}
# Trajectory 44/50 processed. Results: {'smoothness_loss': 0.20427386462688446, 'closed_shape_loss': 12.51227855682373, 'symmetry_loss': 0.7040453553199768, 'shape_preservation_loss': 116.5882797241211, 'final_score': 0.8457326889038086}
# Trajectory 45/50 processed. Results: {'smoothness_loss': 0.3765029311180115, 'closed_shape_loss': 13.121866226196289, 'symmetry_loss': 0.448278546333313, 'shape_preservation_loss': 116.03491973876953, 'final_score': 0.8504487872123718}
# Trajectory 46/50 processed. Results: {'smoothness_loss': 0.1696726530790329, 'closed_shape_loss': 5.882970809936523, 'symmetry_loss': 0.16025958955287933, 'shape_preservation_loss': 62.8175048828125, 'final_score': 0.9007936716079712}
# Trajectory 47/50 processed. Results: {'smoothness_loss': 0.4570082128047943, 'closed_shape_loss': 12.605916023254395, 'symmetry_loss': 1.0710067749023438, 'shape_preservation_loss': 114.63114929199219, 'final_score': 0.8426686525344849}
# Trajectory 48/50 processed. Results: {'smoothness_loss': 0.2982807159423828, 'closed_shape_loss': 12.96018123626709, 'symmetry_loss': 0.810364305973053, 'shape_preservation_loss': 117.02042388916016, 'final_score': 0.8438618779182434}
# Trajectory 49/50 processed. Results: {'smoothness_loss': 0.6094592213630676, 'closed_shape_loss': 13.206287384033203, 'symmetry_loss': 1.6173290014266968, 'shape_preservation_loss': 127.43246459960938, 'final_score': 0.8280881643295288}
# Trajectory 50/50 processed. Results: {'smoothness_loss': 0.17026513814926147, 'closed_shape_loss': 5.83466911315918, 'symmetry_loss': 0.16359034180641174, 'shape_preservation_loss': 61.890045166015625, 'final_score': 0.901496946811676}
#
# --- Final Results ---
# smoothness_loss_mean          : 0.305897
# smoothness_loss_std           : 0.133365
# final_score_mean              : 0.852706
# final_score_std               : 0.020780
# symmetry_loss_mean            : 0.726545
# symmetry_loss_std             : 0.373605
# closed_shape_loss_mean        : 11.693053
# closed_shape_loss_std         : 2.173534
# shape_preservation_loss_mean  : 108.905664
# shape_preservation_loss_std   : 19.910787
